# %% [markdown]
# # This video focuses on downloading and formatting our data set.
# ## First: we get our data from American FactFinder.
# ## Second: we load our tables into the notebook and review some basic information.
# ## Third: we format the column headers of two data frames and merge them using Pandas' pd.merge function.
# # Learning goals for this video:
#    - learn how to read a comma separated value file and skip unwanted rows.
#    - understand the shape of dataframes
#    - the basics of pandas' merge function and how to confirm it worked properly

# %%
import pandas as pd

# %%
t1=pd.read_csv("ACS_17_5YR_DP03/ACS_17_5YR_DP03_with_ann.csv",skiprows=[1])
t2=pd.read_csv("ACS_17_5YR_B25031/ACS_17_5YR_B25031_with_ann.csv", skiprows=[1])
# Out:
# c:\users\c_ull\appdata\local\programs\python\python36\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (9,10,13,14,17,18,21,22,25,26,29,30,37,38,45,46,49,50,53,54,77,78,81,82,85,86,89,90,93,94,97,98,99,100,109,110,113,114,117,118,121,122,125,126,133,134,137,138,141,142,145,146,149,150,153,154,157,158,161,162,165,166,169,170,173,174,177,178,181,182,189,190,193,194,197,198,201,202,351,352,367,368,375,376,385,386,389,390,393,394,397,398,405,406,421,422,425,426,429,430,433,434,441,442,445,446,449,450,453,454,461,462,465,466,469,470,473,474,513,514,533,534,537,538,541,542,549,550) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
t1.head(3)
# Out:
#                  GEO.id      GEO.id2  \
# 0  1400000US13001950100  13001950100
# 1  1400000US13001950200  13001950200
# 2  1400000US13001950300  13001950300
#
#                             GEO.display-label  HC01_VC03  HC02_VC03  \
# 0  Census Tract 9501, Appling County, Georgia       2350        252
# 1  Census Tract 9502, Appling County, Georgia       3586        396
# 2  Census Tract 9503, Appling County, Georgia       4374        423
#
#    HC03_VC03 HC04_VC03  HC01_VC04  HC02_VC04 HC03_VC04     ...     HC03_VC178  \
# 0       2350       (X)       1399        217      59.5     ...           12.1
# 1       3586       (X)       1626        299      45.3     ...           19.3
# 2       4374       (X)       2227        320      50.9     ...           16.9
#
#    HC04_VC178  HC01_VC179 HC02_VC179 HC03_VC179  HC04_VC179  HC01_VC180  \
# 0         8.2         (X)        (X)       12.5         7.8         (X)
# 1         9.3         (X)        (X)       22.1         9.8         (X)
# ...

# %%
t2.head(3)
# Out:
#                  GEO.id      GEO.id2  \
# 0  1400000US13001950100  13001950100
# 1  1400000US13001950200  13001950200
# 2  1400000US13001950300  13001950300
#
#                             GEO.display-label HD01_VD02 HD02_VD02 HD01_VD03  \
# 0  Census Tract 9501, Appling County, Georgia       502       211         -
# 1  Census Tract 9502, Appling County, Georgia       467        80         -
# 2  Census Tract 9503, Appling County, Georgia       523        87         -
#
#   HD02_VD03 HD01_VD04 HD02_VD04 HD01_VD05 HD02_VD05 HD01_VD06 HD02_VD06  \
# 0        **         -        **       435       203         -        **
# 1        **         -        **       410       274       618        32
# 2        **         -        **       527       205       553       123
#
#   HD01_VD07 HD02_VD07 HD01_VD08 HD02_VD08
# 0         -        **         -        **
# 1       437       209         -        **
# 2         -        **         -        **

# %%
print(t1.shape)
print(t2.shape)
# Out:
# (5162, 551)
# (5162, 17)

# %%
pd.merge(t1, t2, on='GEO.id')
# Out:
#                     GEO.id    GEO.id2_x  \
# 0     1400000US13001950100  13001950100
# 1     1400000US13001950200  13001950200
# 2     1400000US13001950300  13001950300
# 3     1400000US13001950400  13001950400
# 4     1400000US13001950500  13001950500
# 5     1400000US13003960100  13003960100
# 6     1400000US13003960200  13003960200
# 7     1400000US13003960300  13003960300
# 8     1400000US13005970100  13005970100
# 9     1400000US13005970201  13005970201
# 10    1400000US13005970202  13005970202
# 11    1400000US13007960100  13007960100
# 12    1400000US13007960200  13007960200
# 13    1400000US13009970100  13009970100
# 14    1400000US13009970200  13009970200
# 15    1400000US13009970300  13009970300
# 16    1400000US13009970400  13009970400
# 17    1400000US13009970500  13009970500
# 18    1400000US13009970600  13009970600
# 19    1400000US13009970701  13009970701
# 20    1400000US13009970702  13009970702
# 21    1400000US13009970800  13009970800
# ...
